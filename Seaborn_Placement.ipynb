# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset= pd.read_csv("Placement_Data_Full_Class.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
print("The number of rows : ",dataset.shape[0])
print("The number of columns : ",dataset.shape[1])
# Out:
# The number of rows :  215
# The number of columns :  15

# %%
dataset.shape
# Out:
# (215, 15)

# %%
# Loading user Define functions

# %%
from Descriptive import Descriptive
obj=Descriptive()

# %% [markdown]
#  # Univariate Analysis

# %%
# dist plot

# %%
sns.distplot(dataset['mba_p'],kde=True,hist=True,kde_kws={'color' : 'red'})
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_9804\3198052650.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['mba_p'],kde=True,hist=True,kde_kws={'color' : 'red'})
# <Axes: xlabel='mba_p', ylabel='Density'>

# %% [markdown]
# # Bivariate Analysis : Distribution plot

# %%
# joint plot

# %%
sns.jointplot(x='etest_p',y='mba_p',data=dataset)

# %%
sns.jointplot(x='mba_p',y='salary',data=dataset,kind='kde')

# %%
sns.scatterplot(x='hsc_p',y='etest_p',data=dataset)
# Out:
# <Axes: xlabel='hsc_p', ylabel='etest_p'>

# %%
sns.jointplot(x='etest_p',y='salary',data=dataset,kind='hex')

# %%
# pairplot

# %%
sns.pairplot(dataset,hue='gender',diag_kind='kde',kind='scatter',palette='bright')
# Out:
# C:\Users\ELCOT\anaconda3\envs\aidata\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # For categorical columns

# %%
# stirpplot

# %%
sns.stripplot(x='degree_t',y='degree_p',data=dataset)
# Out:
# <Axes: xlabel='degree_t', ylabel='degree_p'>

# %%
sns.stripplot(x='degree_t',y='degree_p',data=dataset,jitter=True)
# Out:
# <Axes: xlabel='degree_t', ylabel='degree_p'>

# %%
# swarmplot - used same as stripplot-useful in scenarios where you want to avoid overlapping points
# and provide a better representation of the distribution.

# %%
sns.swarmplot(x='degree_t',y='degree_p',data=dataset)
# Out:
# <Axes: xlabel='degree_t', ylabel='degree_p'>

# %% [markdown]
# # Distribution observation

# %%
# violin plot

# %%
sns.violinplot(x='specialisation',y='mba_p',data=dataset,palette='bright')
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_9784\649180698.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='specialisation',y='mba_p',data=dataset,palette='bright')
# <Axes: xlabel='specialisation', ylabel='mba_p'>

# %%
sns.violinplot(x='specialisation',y='mba_p',data=dataset,palette='bright',hue='gender')
# Out:
# <Axes: xlabel='specialisation', ylabel='mba_p'>

# %%
# box plot - used to display percentile concept,IQR,quartile,outliers

# %%
sns.boxplot(x='degree_t',y='degree_p',data=dataset,hue='gender')
# Out:
# <Axes: xlabel='degree_t', ylabel='degree_p'>

# %%
# bar plot

# %%
sns.barplot(x='degree_t',y='degree_p',data=dataset,hue='gender')
# Out:
# <Axes: xlabel='degree_t', ylabel='degree_p'>

# %%
# countplot - univariate analysis - used to find the count

# %%
sns.countplot(x='degree_t',data=dataset,hue='gender')
# Out:
# <Axes: xlabel='degree_t', ylabel='count'>

# %%
# pointplot=  Point plots are particularly useful when you want to 
#compare the mean or median of a numeric variable across different categories.

# %%
sns.pointplot(x='degree_t',y='degree_p',data=dataset,hue='gender')
# Out:
# <Axes: xlabel='degree_t', ylabel='degree_p'>

# %%
sns.catplot(x='degree_t',y='degree_p',hue='gender',data=dataset,kind='violin')
# Out:
# C:\Users\ELCOT\anaconda3\envs\aidata\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('tips.csv')
sb.regplot(x = "total_bill", y = "tip", data = df)
sb.lmplot(x = "total_bill", y = "tip", data = df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\anaconda3\envs\aidata\Lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File ~\anaconda3\envs\aidata\Lib\http\client.py:1282, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1281 """Send a complete request to the server."""
# -> 1282 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\anaconda3\envs\aidata\Lib\http\client.py:1328, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1327     body = _encode(body, 'body')
# ...
